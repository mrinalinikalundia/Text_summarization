# %%
# !pip install -q bert-extractive-summarizer
# !pip install -q spacy==2.1.3
# !pip install -q transformer==2.2.2
# !pip install -q neuralcoref
# Out:
#      |████████████████████████████████| 5.8 MB 7.6 MB/s
#      |████████████████████████████████| 182 kB 14.7 MB/s
#      |████████████████████████████████| 7.6 MB 74.6 MB/s
#      |████████████████████████████████| 27.7 MB 1.2 MB/s
#   Installing build dependencies ... error
# WARNING: Discarding https://files.pythonhosted.org/packages/77/f3/eb5aece989ecca541c4b5a439cb8a86fe5254b1521925b547609fb3aaf64/spacy-2.1.3.tar.gz#sha256=b1b86ddf6142fa2782b2e0269d040430ae5696eb0224f3e99408897cac7bb506 (from https://pypi.org/simple/spacy/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: /usr/bin/python3 /tmp/pip-standalone-pip-apaemxju/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /tmp/pip-build-env-0se2aho8/overlay --no-warn-script-location -v --no-binary :none: --only-binary :none: -i https://pypi.org/simple --extra-index-url https://us-python.pkg.dev/colab-wheels/public/simple/ -- setuptools 'wheel>0.32.0.<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' thinc==7.0.0.dev6 Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement spacy==2.1.3 (from versions: 0.31, 0.32, 0.33, 0.40, 0.51, 0.52, 0.60, 0.61, 0.62, 0.63, 0.64, 0.65, 0.67, 0.68, 0.70, 0.80, 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.97, 0.98, 0.99, 0.100.0, 0.100.1, 0.100.2, 0.100.3, 0.100.4, 0.100.5, 0.100.6, 0.100.7, 0.101.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.1.0, 1.1.1, 1.1.2, 1.2.0, 1.3.0, 1.4.0, 1.5.0, 1.5.1, 1.6.0, 1.7.0, 1.7.1, 1.7.2, 1.7.3, 1.7.5, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.10.0, 1.10.1, 2.0.0, 2.0.1.dev0, 2.0.1, 2.0.2.dev0, 2.0.2, 2.0.3.dev0, 2.0.3, 2.0.4.dev0, 2.0.4, 2.0.5.dev0, 2.0.5, 2.0.6.dev0, 2.0.6, 2.0.7, 2.0.8, 2.0.9, 2.0.10.dev0, 2.0.10, 2.0.11.dev0, 2.0.11, 2.0.12.dev0, 2.0.12.dev1, 2.0.12, 2.0.13.dev0, 2.0.13.dev1, 2.0.13.dev2, 2.0.13.dev4, 2.0.13, 2.0.14.dev0, 2.0.14.dev1, 2.0.15, 2.0.16.dev0, 2.0.16, 2.0.17.dev0, 2.0.17.dev1, 2.0.17, 2.0.18.dev0, 2.0.18.dev1, 2.0.18, 2.1.0, 2.1.1.dev0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.1.7.dev0, 2.1.7, 2.1.8, 2.1.9, 2.2.0.dev10, 2.2.0.dev11, 2.2.0.dev13, 2.2.0.dev15, 2.2.0.dev17, 2.2.0.dev18, 2.2.0.dev19, 2.2.0, 2.2.1, 2.2.2.dev0, 2.2.2.dev3, 2.2.2.dev4, 2.2.2, 2.2.3.dev0, 2.2.3, 2.2.4, 2.3.0.dev1, 2.3.0, 2.3.1, 2.3.2, 2.3.3.dev0, 2.3.3, 2.3.4, 2.3.5, 2.3.6, 2.3.7, 2.3.8, 2.3.9, 3.0.0, 3.0.1.dev0, 3.0.1, 3.0.2, 3.0.3, 3.0.4, 3.0.5, 3.0.6, 3.0.7, 3.0.8, 3.0.9, 3.1.0, 3.1.1, 3.1.2, 3.1.3, 3.1.4, 3.1.5, 3.1.6, 3.1.7, 3.2.0, 3.2.1, 3.2.2, 3.2.3, 3.2.4, 3.2.5, 3.3.0.dev0, 3.3.0, 3.3.1, 3.3.2, 3.4.0, 3.4.1, 3.4.2, 3.4.3, 3.4.4)
# ERROR: No matching distribution found for spacy==2.1.3
# ERROR: Could not find a version that satisfies the requirement transformer==2.2.2 (from versions: none)
# ERROR: No matching distribution found for transformer==2.2.2
#      |████████████████████████████████| 368 kB 4.5 MB/s
#      |████████████████████████████████| 132 kB 59.8 MB/s
#      |████████████████████████████████| 79 kB 7.6 MB/s
#      |████████████████████████████████| 10.3 MB 63.9 MB/s
#      |████████████████████████████████| 127 kB 63.2 MB/s
#   Building wheel for neuralcoref (setup.py) ... done

# %%
from summarizer import Summarizer
from pprint import pprint
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
with open('/content/Jayaben - Mujeeb Ahmad.txt','r')as file:
  data=file.read().replace('\n', '')

# %%
#text summarizer using bert

# %%
data=data.replace("\ufeff","")

# %%
data[0:1000]
# Out:
# '® SCC Online Web Edition, © 2022 EBC Publishing Pvt. Ltd.SCC Page 1 Thursday, June 02, 2022Printed For: Mujeeb Ahmad, Jamia Millia IslamiaE SCC Online Web Edition: http:/Awww.scconline.comTrue Print’ TruePrint™ source: Supreme Court Cases, © 2022 Eastern Book Company.                        230 SUPREME COURT CASES (2022) 3 SCC(2022) 3 Supreme Court Cases 230(2) (BEFORE M.R. SIIAIT AND B.V. NAGARATIINA, JJ.)Criminal Appeal No. 1655 of 2021JAYABENVersusTEJAS KANUBHAI ZALAAND ANOTHERWithCriminal Appeal No. 1656 of 20217JAYABENVersusJAYSUKHBHAI DEVRAJBHAI RADADIYAAND ANOTHERCriminal Appeals No. 1655 of 2021No. 1656 of 2021, decided on Janu.      in CCTY footages and mobile phone =of crime were recovered — High Courperfunctory and casual manner— In such serious matter and’statements of eyewitnesses an                    : Smpugned judgmentson bail stand quashed(Paras 14 to 19)- 439 — Bail — Cancellation of gide: wrong order passed by court releasingf accused herein that after they were rele'

# %%
model=Summarizer()
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
result=model(data,max_length=300,min_length=150)

# %%
full=''.join(result)

# %%
pprint(full)
# Out:
# ('Ltd.SCC Page 1 Thursday, June 02, 2022Printed For: Mujeeb Ahmad, Jamia '
#  'Millia IslamiaE SCC Online Web Edition: http:/Awww.scconline.comTrue Print’ '
#  'TruePrint™ source: Supreme Court Cases, © 2022 Eastern Book Company. JAYABEN '
#  'v. TEJAS KANUBHAIZALA (M.R. Shah, J.) 233on behalf of Respondent 1-accused '
#  'Tejas Kanubhai Zala and Shri PurvishgJitendra Malkan, learned counsel '
#  'appearing on behalf of Respondent 1l-accusedJaysukhbhai Devrajbhai '
#  'Radadiya.9, Shri Gonsalves, learned Scnior Advocate appearing on behalf of? '
#  'Tt is submittedthat all the accused werboth the eyewitnessesifre egent over '
#  'head tind baie caused by hard and blunt object.cas the High Court ought not '
#  'to have brushed§ t this stage. It is therefore submitted thatthe High Cée '
#  'has materially “géleasing the accused on bail.@. Ms Aastha Mehta, lear '
#  'counsel appearing on behalf of the StateS supported the appellant. Ltd.Page '
#  '5 Thursday, June 02, 2022Printed For: Mujeeb Ahmad, Jamia Millia IslamiaSCC '
#  'Online Web Edition: http:/Awww.scconline.comTruePrint™ source: Supreme Court '
#  'Cases, © 2022 Eastern Book Company.')

# %%
#hugging face transformer

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
summarizer(full, max_length=130, min_length=30, do_sample=False)
# Out:
# [{'summary_text': ' JAYABEN v. TEJAS KANUBHAIZALA (M.R. Shah, J. 233) Jaysukhbhai Devrajbhai Radadiya.9, Shri Gonsalves, learned Scnior Advocate appearing on behalf of. Respondent 1-accused Tejas Kanubhai Zala.9 .'}]

# %%
#bert exctractive summarizer

# %%
import torch

# %%
model1 = Summarizer('distilbert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
import time
start = time.time()
resp=model(data)
end = time.time()

print(f'Response Time: {end-start}')
print(f'Summary: {resp}')
# Out:
# Response Time: 44.26390790939331
# Summary: ® SCC Online Web Edition, © 2022 EBC Publishing Pvt. “4-2019) [Reversed]  SCC Online Web Edition, © 2022 EBC Publishing Pvt. Investigation was carried oGondal division and thereafter by Dy. 3d5, That Respondent 1 herein moved a i€Sessions Court, Gondal seeking release on bail, whichstvide order dated 18-9-2018. Tt is submittedthat all the accused werboth the eyewitnessesifre egent over head tind baie caused by hard and blunt object.cas the High Court ought not to have brushed§ t this stage. The entire incidént has been captured/recorded in the CCTVand the mobile phone. Ltd.Page 6 Thursday, June 02, 2022Printed For: Mujeeb Ahmad, Jamia Millia IslamiaSCC Online Web Edition: http:/Awww.scconline.comTruePrint™ source: Supreme Court Cases, © 2022 Eastern Book Company. JAYABEN v. TEJAS KANUBHAIZALA (M.R. Shah, J.) 235panchnama of the place of the incident has been prepared, statements of thegwitnesses are recorded; test identification of the accused has been carried out;CCTV footages and DVR from the place of incident have been recovered. Pipe.and the belt used in commission of the crime have been recovered. passed by the HighHod secon bail in con g ith first information reportA ‘registered arRol @ tion Shapar (Veraval) for the302, 114, 323 IPC, SSetions 135, 37(1) of the Gujarat             ficreby quashed and sct aside.é exclirect accused Respondent 1 — Tejas             SCC Online Web Edition, © 2022 EBC Publishing Pvt.

# %%
start1 = time.time()
resp1=model1(data)
end1 = time.time()

print(f'Response Time: {end1-start1}')
print(f'Summary: {resp1}')
# Out:
# Response Time: 6.032143592834473
# Summary: ® SCC Online Web Edition, © 2022 EBC Publishing Pvt. 1655 of 2021JAYABENVersusTEJAS KANUBHAI ZALAAND ANOTHERWithCriminal Appeal No. That thereafter five accused persMukeshbhai — husband of the original complainant to the ee of the                                                                           bunconscious and seriously injured. Ltd.Page 5 Thursday, June 02, 2022Printed For: Mujeeb Ahmad, Jamia Millia IslamiaSCC Online Web Edition: http:/Awww.scconline.comTruePrint™ source: Supreme Court Cases, © 2022 Eastern Book Company. JAYABEN v. TEJAS KANUBHAIZALA (M.R. Shah, J.) 235panchnama of the place of the incident has been prepared, statements of thegwitnesses are recorded; test identification of the accused has been carried out;CCTV footages and DVR from the place of incident have been recovered. Now so far as the submissions onated above, both these4 i rs! passed by the HighHod secon bail in con g ith first information reportA ‘registered arRol @ tion Shapar (Veraval) for the302, 114, 323 IPC, SSetions 135, 37(1) of the Gujarat             ficreby quashed and sct aside.é exclirect accused Respondent 1 — Tejas             SCC Online Web Edition, © 2022 EBC Publishing Pvt. releasing the accused on baiin such a serious matter, the State has failed to protect the rights of the viWe are of the opinion that this was the fit case where the State ought t |preferred the appeals challenging the orders passed by the High Court administration of justice in criminal matters is concerned. It is tDirector ot Prosecution to take “Prompt decision. tate Government                   x to prefer anvery ‘serious evento maintain the rule of law inbrutally murdered/killed while     athe Director, f BroseSution and the StateebGokédaind punistig :24.
